# %%
"""ブンデスリーガの試合予想"""

# %%
from selenium import webdriver
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re 
from tqdm import tqdm_notebook as tqdm

# %%
#team_name
html_team = urlopen("https://www.bundesliga.com/en/league/")
soup_team = BeautifulSoup(html_team,"html.parser")

# %%
soup_team
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Bundesliga | Club overview | Season 2017/18 | bundesliga.com</title>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content=" The club overview of Bundesliga teams with complete information, news and statistics " name="description"/>
# <meta content="Clubs, Bundesliga, Club overview, first division, first, top-flight" name="keywords"/>
# <meta content="index, follow" name="robots"/>
# <meta content="bundesliga.com - the official Bundesliga website" name="copyright"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@Bundesliga_EN" name="twitter:site"/> <meta content="https://s.bundesliga.com/assets/img/1090000/1083050_original.jpg" name="twitter:image"/>
# ...

# %%
soup_team.find_all("td",class_="clubs-page-club")[0]

#default > div > div > div > table > tbody > tr:nth-child(1) > td.clubs-page-club > a:nth-child(1)
# Out:
# <td class="clubs-page-club"> <a href=" /en/clubs/bayer-04-leverkusen.jsp " onclick="return trackClub(this, 'Club-Logo', 'B04');"> <i class="logo-00000B" title="Bayer 04 Leverkusen"></i> </a> <a href=" /en/clubs/bayer-04-leverkusen.jsp " onclick="return trackClub(this, 'Club-Name', 'B04');"> <span class="club-name-long"> Bayer 04 Leverkusen </span> </a> <a href=" /en/clubs/bayer-04-leverkusen.jsp " onclick="return trackClub(this, 'Club-Name', 'B04');"> <span class="club-name-short"> B04 </span> </a> </td>

# %%
	soup_team.select(re.compile('a[^jsp]'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-7ddcedff651c> in <module>
# ----> 1 soup_team.select(re.compile('a[^jsp]'))
#
# /usr/local/var/pyenv/versions/anaconda3-5.0.0/lib/python3.6/site-packages/bs4/element.py in select(self, selector, _candidate_generator, limit)
#    1410
#    1411         # Handle grouping selectors if ',' exists, ie: p,a
# -> 1412         if ',' in selector:
#    1413             context = []
#    1414             selectors = [x.strip() for x in selector.split(",")]
#
# TypeError: argument of type '_sre.SRE_Pattern' is not iterable

# %%
#J1各チームの日程・結果にアクセスするためのurlリスト。
html_all = urlopen("https://www.bundesliga.com/en/bundesliga/matchday/2018-2019/?club=ALL")
soup_all = BeautifulSoup(html_all, "html.parser")
team_url = soup_all.find_all("option")
#fixtures > div.row > div.col-md-7.col-xs-12 > div.btn-group.bootstrap-select.club-dropdown

# %%
soup_all
# Out:
#  <!DOCTYPE html>
# <html lang="en">
# <head>
# <script src="//predictor.bundesliga.com/vendor/polyfills/custom-elements-es5-adapter.js" type="text/javascript"></script>
# <script src="//predictor.bundesliga.com/vendor/polyfills/webcomponents-bundle.js" type="text/javascript"></script>
# <script src="//predictor.bundesliga.com/extensions/match_card/index.js" type="text/javascript"></script>
# <meta charset="utf-8"/>
# <title>Bundesliga | Fixtures &amp; Results | 2018/2019</title>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Find all Bundesliga features &amp; results on bundesliga.com" name="description"/>
# <meta content="Bundesliga, Results, Season 2018/2019" name="keywords"/>
# <meta content="index, follow" name="robots"/>
# <meta content="bundesliga.com - the official Bundesliga website" name="copyright"/>
# ...

# %%
team_url
# Out:
# [<option selected="SELECTED" value="/en/bundesliga/matchday/2018-2019/index.jsp">2018/2019</option>,
#  <option value="/en/bundesliga/matchday/2017-2018/index.jsp">2017/2018</option>,
#  <option value="/en/bundesliga/matchday/2016-2017/index.jsp">2016/2017</option>,
#  <option style="display:none" value="?d=0">All</option>,
#  <option value="?d=1">Matchday 1</option>,
#  <option value="?d=2">Matchday 2</option>,
#  <option value="?d=3">Matchday 3</option>,
#  <option value="?d=4">Matchday 4</option>,
#  <option value="?d=5">Matchday 5</option>,
#  <option value="?d=6">Matchday 6</option>,
#  <option value="?d=7">Matchday 7</option>,
#  <option value="?d=8">Matchday 8</option>,
#  <option value="?d=9">Matchday 9</option>,
#  <option value="?d=10">Matchday 10</option>,
#  <option value="?d=11">Matchday 11</option>,
#  <option value="?d=12">Matchday 12</option>,
#  <option selected="SELECTED" value="?d=13">Matchday 13</option>,
#  <option value="?d=14">Matchday 14</option>,
# ...
